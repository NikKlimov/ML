# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'C:\Users\rocki\Downloads\Tomato.csv', header=0, index_col=0, parse_dates=True,
squeeze=True)
df = df.replace(',', '.', regex=True)

# %% [markdown]
# ## Первичная обработка данных и визуализация

# %% [markdown]
# ### Первичный анализ

# %% [markdown]
# Выведем первые 5 строк датасета:

# %%
df.head()
# Out:
#            Unit  Minimum  Maximum  Average  Market
# Date
# 2013-06-16   Kg       26       32     29.0  Tomato
# 2013-06-17   Kg       20       25     22.5  Tomato
# 2013-06-18   Kg       22       26     24.0  Tomato
# 2013-06-19   Kg       24       28     26.0  Tomato
# 2013-06-20   Kg       22       26     24.0  Tomato

# %% [markdown]
# Определим размер датасета:

# %%
df.shape
# Out:
# (2741, 5)

# %%
df = df.head(300)

# %% [markdown]
# Определим типы данных:

# %%
df.dtypes
# Out:
# Unit        object
# Minimum      int64
# Maximum      int64
# Average    float64
# Market      object
# dtype: object

# %% [markdown]
# ### Обработка данных

# %%
def draw_missing(df):
    total = df.isnull().sum().sort_values(ascending=False)
    percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)*100
    missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    return missing_data

# %%
draw_missing(df).round(1)
# Out:
#          Total  Percent
# Unit         0      0.0
# Minimum      0      0.0
# Maximum      0      0.0
# Average      0      0.0
# Market       0      0.0

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler, Normalizer

# %%
sc1 = MinMaxScaler()
df['Average'] = sc1.fit_transform(df[['Average']])
df['Maximum'] = sc1.fit_transform(df[['Maximum']])
df['Minimum'] = sc1.fit_transform(df[['Minimum']])
df
# Out:
#            Unit   Minimum   Maximum   Average  Market
# Date
# 2013-06-16   Kg  0.222222  0.261538  0.242188  Tomato
# 2013-06-17   Kg  0.126984  0.153846  0.140625  Tomato
# 2013-06-18   Kg  0.158730  0.169231  0.164062  Tomato
# 2013-06-19   Kg  0.190476  0.200000  0.195312  Tomato
# 2013-06-20   Kg  0.158730  0.169231  0.164062  Tomato
# ...         ...       ...       ...       ...     ...
# 2014-06-30   Kg  0.063492  0.076923  0.070312  Tomato
# 2014-07-01   Kg  0.063492  0.076923  0.070312  Tomato
# 2014-07-02   Kg  0.031746  0.046154  0.039062  Tomato
# 2014-07-03   Kg  0.047619  0.076923  0.062500  Tomato
# 2014-07-04   Kg  0.031746  0.046154  0.039062  Tomato
#
# [300 rows x 5 columns]

# %%
df
# Out:
#            Unit   Minimum   Maximum   Average  Market
# Date
# 2013-06-16   Kg  0.222222  0.261538  0.242188  Tomato
# 2013-06-17   Kg  0.126984  0.153846  0.140625  Tomato
# 2013-06-18   Kg  0.158730  0.169231  0.164062  Tomato
# 2013-06-19   Kg  0.190476  0.200000  0.195312  Tomato
# 2013-06-20   Kg  0.158730  0.169231  0.164062  Tomato
# ...         ...       ...       ...       ...     ...
# 2014-06-30   Kg  0.063492  0.076923  0.070312  Tomato
# 2014-07-01   Kg  0.063492  0.076923  0.070312  Tomato
# 2014-07-02   Kg  0.031746  0.046154  0.039062  Tomato
# 2014-07-03   Kg  0.047619  0.076923  0.062500  Tomato
# 2014-07-04   Kg  0.031746  0.046154  0.039062  Tomato
#
# [300 rows x 5 columns]

# %%
df = df.drop(columns=['Unit'], axis=1)
df = df.drop(columns=['Minimum'], axis=1)
df = df.drop(columns=['Maximum'], axis=1)
df = df.drop(columns=['Market'], axis=1)

# %% [markdown]
# ### Основные статистические характеристки

# %%
df.describe()
# Out:
#           Average
# count  300.000000
# mean     0.352604
# std      0.212951
# min      0.000000
# 25%      0.218750
# 50%      0.296875
# 75%      0.453125
# max      1.000000

# %% [markdown]
# ### Визуализация исходного временного ряда

# %%
fig, ax = pyplot.subplots(1, 1, sharex='col', sharey='row', figsize=(10,5))
fig.suptitle('Временной ряд в виде графика')
df.plot(ax=ax, legend=False)
pyplot.show()

# %%
fig, ax = pyplot.subplots(1, 1, sharex='col', sharey='row', figsize=(10,5))
fig.suptitle('Первые 30 точек ряда')
df[:30].plot(ax=ax, legend=False)
pyplot.show()

# %%
fig, ax = pyplot.subplots(1, 1, sharex='col', sharey='row', figsize=(10,5))
fig.suptitle('Гистограмма')
df.hist(ax=ax, legend=False)
pyplot.show()

# %%
fig, ax = pyplot.subplots(1, 1, sharex='col', sharey='row', figsize=(10,5))
fig.suptitle('Плотность вероятности распределения данных')
df.plot(ax=ax, kind='kde', legend=False)
pyplot.show()

# %%
for i in range(1, 5):
    fig, ax = pyplot.subplots(1, 1, sharex='col', sharey='row', figsize=(5,4))
    fig.suptitle(f'Лаг порядка {i}')
    pd.plotting.lag_plot(df, lag=i, ax=ax)
    pyplot.show()

# %% [markdown]
# Наблюдается достаточно сильная положительная корреляция.

# %% [markdown]
# Автокорреляционная диаграмма:

# %%
fig, ax = pyplot.subplots(1, 1, sharex='col', sharey='row', figsize=(10,5))
fig.suptitle('Автокорреляционная диаграмма')
pd.plotting.autocorrelation_plot(df, ax=ax)
pyplot.show()

# %% [markdown]
# Автокорреляционная функция:

# %%
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(df, lags=30)
plt.tight_layout()

# %% [markdown]
# Частичная автокорреляционная функция:

# %%
from statsmodels.graphics.tsaplots import plot_pacf
plot_pacf(df, lags=30)
plt.tight_layout()

# %% [markdown]
# Временной ряд со скользящими средними:

# %%
df2 = df.copy()

# %%
df2['SMA_10'] = df2['Average'].rolling(10, min_periods=1).mean()
df2['SMA_20'] = df2['Average'].rolling(20, min_periods=1).mean()

# %%
fig, ax = pyplot.subplots(1, 1, sharex='col', sharey='row', figsize=(10,5))
fig.suptitle('Временной ряд со скользящими средними')
df2[:100].plot(ax=ax, legend=True)
pyplot.show()

# %% [markdown]
# ## Прогнозирование временного ряда с использованием авторегрессионного метода

# %% [markdown]
# Будем использовать авторегриссионный метод ARIMA:

# %%
from statsmodels.tsa.arima.model import ARIMA

# %% [markdown]
# Разделение выборки на обучающую и тестовую

# %%
xnum = list(range(df2.shape[0]))
Y = df2['Average'].values
train_size = int(len(Y) * 0.7)
xnum_train, xnum_test = xnum[0:train_size], xnum[train_size:]
train, test = Y[0:train_size], Y[train_size:]
history_arima = [x for x in train]

# %% [markdown]
# ## Прогноз ARIMA

# %%
arima_order = (6, 1, 0)
predictions_arima = list()
for t in range(len(test)):
    model_arima = ARIMA(history_arima, order=arima_order)
    model_arima_fit = model_arima.fit()
    yhat_arima = model_arima_fit.forecast()[0]
    predictions_arima.append(yhat_arima)
    history_arima.append(test[t])

# %%
df2['predictions_ARIMA'] = (train_size * [np.NAN]) + list(predictions_arima)

# %%
fig, ax = pyplot.subplots(1, 1, sharex='col', sharey='row', figsize=(20,10))
fig.suptitle('Предсказания временного ряда')
df2.plot(ax=ax, legend=True)
pyplot.show()

# %%
fig, ax = pyplot.subplots(1, 1, sharex='col', sharey='row', figsize=(20,10))
fig.suptitle('Предсказания временного ряда (тестовая выборка)')
df2[train_size:].plot(ax=ax, legend=True)
pyplot.show()

# %% [markdown]
# Предсказания ARIMA точны, близки к исходному, далеки от среднего скользящего.

# %% [markdown]
# ## Метрики

# %% [markdown]
# MAE и MSE:

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mean_squared_error(test, predictions_arima, squared=False)
# Out:
# 0.06977076012984242

# %%
mean_absolute_error(test, predictions_arima)
# Out:
# 0.053066613469521094

# %% [markdown]
# ## Прогнозирование временного ряда с использованием метода символьной регрессии

# %% [markdown]
# Будем использовать библиотеку gplearn:

# %%
# pip install gplearn

# %%
from gplearn.genetic import SymbolicRegressor

# %%
function_set = ['add', 'sub', 'mul', 'div', 'sin']
est_gp = SymbolicRegressor(population_size=500, metric='mse',
                               generations=200, stopping_criteria=0.01,
                               init_depth=(4, 10), verbose=1, function_set=function_set,
                               const_range=(-10, 10), random_state=0)

# %%
est_gp.fit(np.array(xnum_train).reshape(-1, 1), train.reshape(-1, 1))
# Out:
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
#    0   263.65      3.27398e+50       14         0.108991              N/A     14.86m
#    1    68.74      2.42434e+12       18         0.050162              N/A      3.68m
#    2    16.67      5.89295e+07       18        0.0484429              N/A      2.22m
#    3    18.60       3.8058e+06       31        0.0477716              N/A      2.41m
#    4    14.46          47.1214       10        0.0484429              N/A      2.33m
#    5     7.85           768774       10        0.0484429              N/A      1.94m
#    6     4.48          65.4402       10        0.0484429              N/A      1.95m
#    7     3.92          2076.39        4        0.0514879              N/A      1.89m
#    8     3.91          34.2876        4        0.0514879              N/A      1.77m
#    9     3.94          34.5414        4        0.0514879              N/A      1.65m
#   10     4.36          18096.1        4        0.0514879              N/A      1.87m
#   11     4.23          481.379        4        0.0514879              N/A      1.98m
#   12     4.07          29.1847        4        0.0514879              N/A      1.89m
#   13     3.97           779240        4        0.0514879              N/A      2.09m
#   14     4.03           768938        4        0.0514879              N/A      1.96m
#   15     4.02           123112        4        0.0514879              N/A      1.87m
#   16     4.06          32.7748        4        0.0514879              N/A      1.90m
#   17     4.03          306.826        4        0.0514879              N/A      1.97m
#   18     4.13          143.349        4        0.0514879              N/A      2.22m
#   19     3.99           32.602        4        0.0514879              N/A      1.74m
#   20     4.15           768758        4        0.0514879              N/A      1.71m
#   21     4.14           123175        4        0.0514879              N/A      1.77m
#   22     4.05          141.086        4        0.0514879              N/A      1.74m
#   23     4.07           390088        4        0.0514879              N/A      1.87m
#   24     3.98          832.331        4        0.0514879              N/A      1.97m
#   25     3.99          36.2841        4        0.0514879              N/A      1.76m
#   26     3.95          124.515        4        0.0514879              N/A      1.87m
#   27     4.10          33.8628        4        0.0514879              N/A      1.98m
#   28     4.05          61.8467        4        0.0514879              N/A      2.10m
#   29     4.08          57.1635        4        0.0514879              N/A      1.75m
#   30     3.96          32.5494        4        0.0514879              N/A      1.81m
#   31     4.13      2.43669e+09        4        0.0514879              N/A      1.65m
#   32     3.97          91.9112        4        0.0514879              N/A      1.84m
#   33     4.03          29.3678        4        0.0514879              N/A      1.73m
#   34     4.05          450.703        4        0.0514879              N/A      1.73m
#   35     4.01      6.94243e+10        4        0.0514879              N/A      1.49m
#   36     4.00          56.9795        4        0.0514879              N/A      1.64m
#   37     4.09           100043        4        0.0514879              N/A      1.65m
#   38     4.00          34.4864        4        0.0514879              N/A      1.71m
#   39     3.99          64.1409        4        0.0514879              N/A      1.58m
#   40     3.98          58.1061        4        0.0514879              N/A      1.62m
#   41     4.08          28.5085        4        0.0514879              N/A      1.52m
#   42     3.89          729.397        4        0.0514879              N/A      1.78m
#   43     4.09          55.5045        4        0.0514879              N/A      1.44m
#   44     4.00          213.076        4        0.0514879              N/A      1.49m
#   45     3.98          2805.29        4        0.0514879              N/A      1.42m
#   46     4.02          33.8918        4        0.0514879              N/A      1.65m
#   47     3.98          592.419        4        0.0514879              N/A      1.60m
#   48     4.07          187.843        4        0.0514879              N/A      1.63m
#   49     4.00          60.2005        4        0.0514879              N/A      1.47m
#   50     4.01          1302.67        4        0.0514879              N/A      1.41m
#   51     3.96           30.651        4        0.0514879              N/A      1.38m
#   52     4.23          570.802        4        0.0514879              N/A      1.56m
#   53     4.03           768737        4        0.0494775              N/A      1.54m
#   54     4.01          254.866        4        0.0494775              N/A      1.45m
#   55     4.13          60.1393        4        0.0494775              N/A      1.41m
#   56     4.23          904.988        4        0.0494775              N/A      1.60m
#   57     3.93           768734        4        0.0494775              N/A      1.44m
#   58     4.05          55.8879        4        0.0494775              N/A      1.60m
#   59     3.99          33.7055        4        0.0494775              N/A      1.85m
#   60     4.21           59.884        4        0.0494775              N/A      1.44m
#   61     4.05          352.624        4        0.0494775              N/A      1.37m
#   62     4.00          32.5447        4        0.0494775              N/A      1.37m
#   63     4.04          60.7794        4        0.0494775              N/A      1.33m
#   64     3.94          7102.33        4        0.0494775              N/A      1.41m
#   65     4.10          63.6943        4        0.0494775              N/A      1.59m
#   66     3.96          9970.47        4        0.0494775              N/A      1.47m
#   67     3.94           174.96        4        0.0494775              N/A      1.41m
#   68     3.92          32.5018        4        0.0494775              N/A      1.39m
#   69     3.98          5587.01        4        0.0494775              N/A      1.36m
#   70     4.23          25.4191        4        0.0494775              N/A      1.36m
#   71     4.08          35.4327        4        0.0494775              N/A      1.42m
#   72     4.20          32.9432        4        0.0494775              N/A      1.37m
#   73     4.07          29.8237        4        0.0494775              N/A      1.45m
#   74     4.04          32.2558        4        0.0494775              N/A      1.24m
#   75     4.03          13222.6        4        0.0494775              N/A      1.32m
#   76     4.16          27.3954        4        0.0494775              N/A      1.22m
#   77     4.20          28.3552        4        0.0494775              N/A      1.21m
#   78     4.02          31.6612        4        0.0494775              N/A      1.31m
#   79     4.20      9.27073e+06        4        0.0494775              N/A      1.25m
#   80     3.93           768706        4        0.0494775              N/A      1.13m
#   81     4.27          30.3704        4        0.0494775              N/A      1.24m
#   82     3.97          34.2435        4        0.0494775              N/A      1.13m
#   83     4.16           141.95        4        0.0494775              N/A      1.27m
#   84     4.12           770975        4        0.0494775              N/A      1.23m
#   85     4.04          311.525        4        0.0494775              N/A      1.13m
#   86     4.02          752.969        4        0.0494775              N/A      1.20m
#   87     4.07          34.9404        4        0.0494775              N/A      1.27m
#   88     3.93          65.5436        4        0.0494775              N/A      1.07m
#   89     4.36          34.9476        4        0.0494775              N/A      1.14m
#   90     3.97          2483.16        4        0.0494775              N/A      1.15m
#   91     3.95          31.1164        4        0.0494775              N/A      1.14m
#   92     4.05           777363        4        0.0494775              N/A      1.12m
#   93     4.16          969.371        4        0.0494775              N/A      1.08m
#   94     3.97          59.4197        4        0.0494775              N/A      1.19m
#   95     4.20          154.021        4        0.0494775              N/A      1.06m
#   96     4.09          488.355        4        0.0494775              N/A      1.06m
#   97     4.01          209.267        4        0.0494775              N/A      1.07m
#   98     4.41          62.2298        4        0.0494775              N/A      1.19m
#   99     4.27          57.0012        4        0.0494775              N/A      1.15m
#  100     4.09          1403.47        4        0.0494775              N/A      1.20m
#  101     4.10          30.1636        4        0.0494775              N/A      1.41m
#  102     4.05          1892.15        4        0.0494775              N/A      1.03m
#  103     4.05           31.973        4        0.0494775              N/A      1.08m
#  104     4.01          93.9222        4        0.0494775              N/A      1.09m
#  105     3.94          150.316        4        0.0494775              N/A      1.01m
#  106     3.97          57.3234        4        0.0494775              N/A      1.05m
#  107     4.11      4.68461e+10        4        0.0494775              N/A      1.06m
#  108     4.00           768711        4        0.0494775              N/A      1.01m
#  109     3.93          33.2351        4        0.0494775              N/A      1.12m
#  110     4.08      6.67764e+06        4        0.0494775              N/A     59.44s
#  111     3.99          461.116        4        0.0494775              N/A     59.77s
#  112     4.12          1399.25        4        0.0494775              N/A     58.06s
#  113     3.97          206.492        4        0.0494775              N/A     56.46s
#  114     4.09          9744.37        4        0.0494775              N/A     54.87s
#  115     3.99          54.9563        4        0.0494775              N/A      1.08m
#  116     3.96          41.4423        4        0.0494775              N/A     57.44s
#  117     4.14      1.28156e+06        4        0.0494775              N/A     52.28s
#  118     3.99          32.8507        4        0.0494775              N/A     51.71s
#  119     4.01          86.7529        4        0.0494775              N/A     50.95s
#  120     4.09           768702        4        0.0494775              N/A     50.81s
#  121     4.08          61.1916        4        0.0494775              N/A     48.02s
#  122     4.25          34.4882        4        0.0494775              N/A     46.49s
#  123     3.97           768710        4        0.0494775              N/A     49.39s
#  124     4.06          56.8184        4        0.0494775              N/A     51.14s
#  125     4.07          40.6888        4        0.0494775              N/A     51.13s
#  126     3.88          149.378        4        0.0494775              N/A     49.80s
#  127     3.16          16.3617        5        0.0485133              N/A     48.57s
#  128     3.02         0.157119        5        0.0485133              N/A     47.73s
#  129     3.23          28.7119        5        0.0485133              N/A     47.64s
#  130     2.99         0.138465        5        0.0485133              N/A     49.37s
#  131     3.01          0.37733        5        0.0485133              N/A     46.90s
#  132     3.04         0.134519        5        0.0485133              N/A     50.49s
#  133     3.03         0.187286        5        0.0485133              N/A     45.74s
#  134     3.13      3.26281e+08        5        0.0485133              N/A     45.46s
#  135     3.01         0.395008        5        0.0485133              N/A     44.07s
#  136     3.21      1.04921e+06        5        0.0485133              N/A     41.46s
#  137     3.01         0.177703        5        0.0485133              N/A     37.98s
#  138     2.63          27.1525        5         0.048442              N/A     36.61s
#  139     1.99          1861.57        3        0.0490939              N/A     38.52s
#  140     2.04          33.8111        3        0.0490939              N/A     36.07s
#  141     2.02          2684.51        3        0.0490939              N/A     35.81s
#  142     2.02          5.51517        3        0.0490939              N/A     33.62s
#  143     2.41      1.67729e+07        3        0.0490939              N/A     42.06s
#  144     2.01          117.572        3        0.0490939              N/A     32.00s
#  145     2.14          4.54054        3        0.0490939              N/A     37.60s
#  146     2.03          1180.41        3        0.0490939              N/A     32.83s
#  147     2.09          5914.82        3        0.0490939              N/A     32.73s
#  148     2.36           770908        3        0.0490939              N/A     34.03s
#  149     2.08           981386        3        0.0490939              N/A     33.10s
#  150     2.04      1.66088e+07        3        0.0490939              N/A     31.10s
#  151     2.09          6.38447        3        0.0490939              N/A     29.90s
#  152     2.00          7.58021        3        0.0490939              N/A     31.02s
#  153     2.06          5.66222        3        0.0490939              N/A     29.73s
#  154     2.08          631.983        3        0.0490939              N/A     28.02s
#  155     2.00          39.6067        3        0.0490939              N/A     28.91s
#  156     2.04          7.97873        3        0.0490939              N/A     25.58s
#  157     2.18          490.653        3        0.0490939              N/A     26.78s
#  158     2.17       1.8911e+07        3        0.0490939              N/A     28.23s
#  159     2.03           772665        3        0.0490939              N/A     25.88s
#  160     2.04          951.717        3        0.0490939              N/A     26.00s
#  161     2.04           768677        3        0.0490939              N/A     26.80s
#  162     2.05        5.048e+07        3        0.0490939              N/A     22.28s
#  163     2.08      9.63926e+10        3        0.0490939              N/A     23.81s
#  164     2.00          124.244        3        0.0490939              N/A     23.64s
#  165     1.99      2.43977e+10        3        0.0490939              N/A     23.82s
#  166     2.04          82.7207        3        0.0490939              N/A     24.38s
#  167     2.35          4.69043        3        0.0490939              N/A     23.34s
#  168     2.08           693328        3        0.0490939              N/A     21.53s
#  169     2.01          6.47179        3        0.0490939              N/A     21.03s
#  170     2.00           35.578        3        0.0490939              N/A     18.11s
#  171     2.01          217.702        3        0.0490939              N/A     17.14s
#  172     2.04          35.2891        3        0.0490939              N/A     16.69s
#  173     2.12      8.66679e+13        3        0.0490939              N/A     18.15s
#  174     2.06      1.97638e+06        3        0.0490939              N/A     16.95s
#  175     2.06          43.1993        3        0.0490939              N/A     16.73s
#  176     2.00          519.687        3        0.0490939              N/A     16.05s
#  177     2.05          284.293        3        0.0490939              N/A     15.17s
#  178     2.01          43.9458        3        0.0490939              N/A     13.17s
#  179     2.11          16655.7        3        0.0490939              N/A     14.27s
#  180     2.05          4777.55        3        0.0490939              N/A     17.03s
#  181     2.07          217.461        3        0.0490939              N/A     13.75s
#  182     2.07      2.28829e+07        3        0.0490939              N/A     12.35s
#  183     2.02          4087.57        3        0.0490939              N/A     10.74s
#  184     2.03          2778.18        3        0.0490939              N/A      9.84s
#  185     2.02           768684        3        0.0490939              N/A      9.44s
#  186     2.02          5.36567        3        0.0490939              N/A      8.14s
#  187     2.07          33.4665        3        0.0490939              N/A      8.46s
#  188     2.07      1.92542e+10        3        0.0490939              N/A      8.01s
#  189     1.99          665.751        3        0.0490939              N/A      7.08s
#  190     2.02           248.75        3        0.0490939              N/A      6.72s
#  191     2.06      1.54027e+06        3        0.0490939              N/A      6.18s
#  192     2.22           973720        3        0.0490939              N/A      5.57s
#  193     2.04          2628.96        3        0.0490939              N/A      4.73s
#  194     2.05          37.3204        3        0.0490939              N/A      3.70s
#  195     2.28      5.55159e+27        3        0.0490939              N/A      2.98s
#  196     2.17           8019.5        3        0.0490939              N/A      2.35s
#  197     2.07      2.87662e+08        3        0.0490939              N/A      1.40s
#  198     1.99          124.172        3        0.0490939              N/A      0.64s
#  199     2.01          13.1812        3        0.0490939              N/A      0.00s
# SymbolicRegressor(const_range=(-10, 10),
#                   function_set=['add', 'sub', 'mul', 'div', 'sin'],
#                   generations=200, init_depth=(4, 10), metric='mse',
#                   population_size=500, random_state=0, stopping_criteria=0.01,
#                   verbose=1)

# %%
y_gp = est_gp.predict(np.array(xnum_test).reshape(-1, 1))
y_gp[:30]
# Out:
# array([0.41598633, 0.41598633, 0.41598633, 0.41598633, 0.41598633,
#        0.41598633, 0.41598633, 0.41598633, 0.41598633, 0.41598633,
#        0.41598633, 0.41598633, 0.41598633, 0.41598633, 0.41598633,
#        0.41598633, 0.41598633, 0.41598633, 0.41598633, 0.41598633,
#        0.41598633, 0.41598633, 0.41598633, 0.41598633, 0.41598633,
#        0.41598633, 0.41598633, 0.41598633, 0.41598633, 0.41598633])

# %%
df2['predictions_GPLEARN'] = (train_size * [np.NAN]) + list(y_gp)

# %% [markdown]
# ## Метрики

# %% [markdown]
# MAE и MSE:

# %%
mean_squared_error(test, y_gp, squared=False)
# Out:
# 0.22247579153806007

# %%
mean_absolute_error(test, y_gp)
# Out:
# 0.18349001963901593

# %% [markdown]
# ## Multi

# %%
import gmdh
import seaborn as sns
# Out:
# C:\Users\rocki\anaconda3\lib\site-packages\seaborn\rcmod.py:82: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(mpl.__version__) >= "3.0":
# C:\Users\rocki\anaconda3\lib\site-packages\setuptools\_distutils\version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)

# %%
df
# Out:
#              Average
# Date
# 2013-06-16  0.242188
# 2013-06-17  0.140625
# 2013-06-18  0.164062
# 2013-06-19  0.195312
# 2013-06-20  0.164062
# ...              ...
# 2014-06-30  0.070312
# 2014-07-01  0.070312
# 2014-07-02  0.039062
# 2014-07-03  0.062500
# 2014-07-04  0.039062
#
# [300 rows x 1 columns]

# %%
df['Average']
# Out:
# Date
# 2013-06-16    0.242188
# 2013-06-17    0.140625
# 2013-06-18    0.164062
# 2013-06-19    0.195312
# 2013-06-20    0.164062
#                 ...
# 2014-06-30    0.070312
# 2014-07-01    0.070312
# 2014-07-02    0.039062
# 2014-07-03    0.062500
# 2014-07-04    0.039062
# Name: Average, Length: 300, dtype: float64
